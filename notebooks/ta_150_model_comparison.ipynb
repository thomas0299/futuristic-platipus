# %% [markdown]
# # Model comparison

# %%
# importing relevant packages and functions
# %run /Users/thomasadler/Desktop/futuristic-platipus/notebooks/ta_00_packages_functions.py
# Out:
# /Users/thomasadler/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# # Preparing data

# %%
#load all files
path = model_filepath
files = glob.glob(path + "/*.csv")

# %%
#concatenate all files
all_models_comparison = []

for file in files:
    df = pd.read_csv(file, index_col=None, header=0)
    all_models_comparison.append(df)

# %%
#make it into a dataframe
model_comparison_df = pd.concat(all_models_comparison, axis=0, ignore_index=True)
model_comparison_df=model_comparison_df.iloc[:,1:]

#check
model_comparison_df
# Out:
#                   Model                                         Parameters  \
# 0               XGBoost  Max depth=6, Gamma=0, Learning rate=0.3, Numbe...
# 1   K Nearest Neighbors                       Neighbors=4, Standard Scaler
# 2  Gaussian Naive Bayes                                                NaN
# 3            Linear SVC               Penalty=l2, C=0.001, Standard Scaler
# 4         Decision Tree  Max depth=24, Min samples leaf=25, Criterion=e...
# 5    Random Forest Tree  Max depth=31, Min samples leaf=11, Criterion=e...
# 6              AdaBoost                Learning rate=1, Number of trees=50
# 7   Logistic Regression                 Penalty=l2, C=0.1, Standard Scaler
#
#    Accuracy Train  Precision Train  Recall Train  F1 Train  \
# 0        0.841840         0.842494      0.841840  0.841765
# 1        0.870462         0.884488      0.870462  0.869269
# 2        0.612033         0.614446      0.612033  0.609977
# 3        0.652100         0.652120      0.652100  0.652089
# 4        0.840593         0.840817      0.840593  0.840567
# 5        0.897099         0.897332      0.897099  0.897084
# 6        0.704895         0.706307      0.704895  0.704390
# 7        0.651419         0.651419      0.651419  0.651419
#
#                                       FPR Train Plot  \
# 0  [0.         0.         0.         ... 0.999478...
# 1  [0.         0.         0.03403824 0.11746813 0...
# 2  [0.         0.         0.         ... 0.999927...
# 3  [0.         0.         0.         ... 0.999652...
# 4  [0.00000000e+00 0.00000000e+00 1.44961150e-05 ...
# 5  [0.         0.         0.         ... 0.998811...
# 6  [0.         0.         0.         ... 0.999927...
# 7  [0.         0.         0.         ... 0.999652...
#
#                                       TPR Train Plot  ROC AUC Train  \
# 0  [0.00000000e+00 1.44961150e-05 2.46433956e-04 ...       0.924392
# 1  [0.         0.58492661 0.77496138 0.91270761 1...       0.967214
# 2  [0.00000000e+00 1.44961150e-05 2.46433956e-04 ...       0.658882
# 3  [0.00000000e+00 1.44961150e-05 4.78371796e-04 ...       0.710458
# 4  [0.         0.35066102 0.35134234 0.35200916 0...       0.929637
# 5  [0.00000000e+00 7.10309637e-04 7.39301867e-04 ...       0.966498
# 6  [0.00000000e+00 1.44961150e-05 1.01472805e-04 ...       0.777469
# 7  [0.00000000e+00 1.44961150e-05 4.78371796e-04 ...       0.710467
#
#                                 Precision Train Plot  ...  \
# 0  [0.51869619 0.51869257 0.51869647 ... 1.      ...  ...
# 1  [0.75726664 0.88597272 0.95792552 1.         1...  ...
# 2  [0.50001812 0.5000145  0.50001812 ... 1.      ...  ...
# 3  [0.50008699 0.50008337 0.50008699 ... 1.      ...  ...
# 4  [0.58853038 0.58938474 0.58985147 0.59074675 0...  ...
# 5  [0.54939751 0.54939392 0.5493983  ... 1.      ...  ...
# 6  [0.50001812 0.5000145  0.50002175 ... 1.      ...  ...
# 7  [0.50008699 0.50008337 0.50007974 ... 1.      ...  ...
#
#                                     Recall Test Plot  PR AUC Test    Time Fit  \
# 0  [1.00000000e+00 9.99941914e-01 9.99941914e-01 ...     0.940467   22.398069
# 1  [1.         0.93766885 0.83288306 0.68564261 0...     0.918197    0.056236
# 2  [1.00000000e+00 9.99941914e-01 9.99941914e-01 ...     0.857439    0.223579
# 3  [1.00000000e+00 9.99941914e-01 9.99883829e-01 ...     0.870835    2.384315
# 4  [1.         0.98646608 0.98629182 0.98623374 0...     0.929016    6.552584
# 5  [1.00000000e+00 9.99941914e-01 9.99941914e-01 ...     0.945374  113.664119
# 6  [1.00000000e+00 9.99767658e-01 9.99709572e-01 ...     0.906179   83.353167
# 7  [1.00000000e+00 9.99941914e-01 9.99883829e-01 ...     0.870664    0.623483
#
#    Time Predict  Precision Non-functioning Test  Recall Non-functioning Test  \
# 0      0.036242                            0.45                         0.65
# 1      0.184799                            0.33                         0.65
# 2      0.041269                            0.27                         0.47
# 3      0.008192                            0.28                         0.55
# 4      0.027779                            0.41                         0.62
# 5      1.130243                            0.48                         0.62
# 6      0.913205                            0.32                         0.64
# 7      0.002351                            0.65                         0.65
#
#   F1 Non-functioning Test Precision Functioning Test  Recall Functioning Test  \
# 0                    0.53                      90.00                    80.00
# 1                    0.44                       0.89                     0.69
# 2                    0.34                       0.84                     0.69
# 3                    0.37                       0.85                     0.65
# 4                    0.49                       0.89                     0.78
# 5                    0.54                       0.90                     0.83
# 6                    0.42                       0.88                     0.66
# 7                    0.65                       0.65                     0.65
#
#   F1 Functioning Test
# 0               85.00
# 1                0.77
# 2                0.75
# 3                0.74
# 4                0.83
# 5                0.87
# 6                0.76
# 7                0.65
#
# [8 rows x 30 columns]

# %% [markdown]
# # ROC Curve for Train/Test

# %% [markdown]
# # Plot accuracy score for Train/Test

# %% [markdown]
# # Plot Precision/Recall/F1 for Functioning/Non-functioning Test

# %% [markdown]
# # Time fit

# %% [markdown]
# # Time predict

# %% [markdown]
# # Visualise feature importance of best model
