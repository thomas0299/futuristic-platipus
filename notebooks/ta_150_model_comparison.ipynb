# %% [markdown]
# # Model comparison

# %%
# importing relevant packages and functions
# %run /Users/thomasadler/Desktop/futuristic-platipus/notebooks/ta_00_packages_functions.py
# Out:
# /Users/thomasadler/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# # Preparing data

# %%
#load all files
path = model_filepath
files = glob.glob(path + "/*.csv")

# %%
#concatenate all files
all_models_comparison = []

for file in files:
    df = pd.read_csv(file, index_col=None, header=0)
    all_models_comparison.append(df)

# %%
#make it into a dataframe
model_comparison_df = pd.concat(all_models_comparison, axis=0, ignore_index=True)

#check
model_comparison_df
# Out:
#    Unnamed: 0                 Model  \
# 0           0               XGBoost
# 1           0   K Nearest Neighbors
# 2           0  Gaussian Naive Bayes
# 3           0            Linear SVC
# 4           0         Decision Tree
# 5           0    Random Forest Tree
# 6           0              AdaBoost
# 7           0   Logistic Regression
#
#                                           Parameters  Accuracy Train  \
# 0  Max depth=6, Gamma=0, Learning rate=0.3, Numbe...        0.841840
# 1                       Neighbors=5, Standard Scaler        0.887577
# 2                                                NaN        0.612033
# 3               Penalty=l2, C=0.001, Standard Scaler        0.652100
# 4  Max depth=24, Min samples leaf=25, Criterion=e...        0.840579
# 5  Max depth=38, Min samples leaf=5, Criterion=en...        0.998790
# 6                Learning rate=1, Number of trees=50        0.704895
# 7                 Penalty=l2, C=0.1, Standard Scaler        0.651419
#
#    Precision Train  Recall Train  F1 Train  \
# 0         0.842494      0.841840  0.841765
# 1         0.890856      0.887577  0.887341
# 2         0.614446      0.612033  0.609977
# 3         0.652120      0.652100  0.652089
# 4         0.840795      0.840579  0.840554
# 5         0.998790      0.998790  0.998790
# 6         0.706307      0.704895  0.704390
# 7         0.651419      0.651419  0.651419
#
#                                       FPR Train Plot  \
# 0  [0.         0.         0.         ... 0.999478...
# 1  [0.         0.         0.02254732 0.06662804 0...
# 2  [0.         0.         0.         ... 0.999927...
# 3  [0.         0.         0.         ... 0.999652...
# 4  [0.00000000e+00 0.00000000e+00 1.44961150e-05 ...
# 5  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ...
# 6  [0.         0.         0.         ... 0.999927...
# 7  [0.         0.         0.         ... 0.999652...
#
#                                       TPR Train Plot  ROC AUC Train  ...  \
# 0  [0.00000000e+00 1.44961150e-05 2.46433956e-04 ...       0.924392  ...
# 1  [0.         0.550309   0.72107957 0.84178254 0...       0.965929  ...
# 2  [0.00000000e+00 1.44961150e-05 2.46433956e-04 ...       0.658882  ...
# 3  [0.00000000e+00 1.44961150e-05 4.78371796e-04 ...       0.710458  ...
# 4  [0.         0.35106691 0.35174823 0.35308187 0...       0.929614  ...
# 5  [0.         0.18875391 0.18878291 0.1887974  0...       0.999947  ...
# 6  [0.00000000e+00 1.44961150e-05 1.01472805e-04 ...       0.777469  ...
# 7  [0.00000000e+00 1.44961150e-05 4.78371796e-04 ...       0.710467  ...
#
#   Recall Test   F1 Test                                      FPR Test Plot  \
# 0    0.771517  0.786053  [0.         0.         0.         ... 0.977967...
# 1    0.740787  0.758709  [0.         0.16092874 0.28342674 0.41072858 0...
# 2    0.642347  0.673018  [0.         0.         0.         ... 0.999763...
# 3    0.631198  0.666512  [0.         0.         0.         ... 0.999763...
# 4    0.751225  0.768004  [0.         0.06846719 0.0687041  0.06965174 0...
# 5    0.810794  0.813209  [0.         0.00544895 0.00544895 0.00544895 0...
# 6    0.657461  0.690728  [0.         0.         0.         ... 0.999289...
# 7    0.626813  0.662988  [0.         0.         0.         ... 0.999526...
#
#                                        TPR Test Plot  ROC AUC Test  \
# 0  [0.00000000e+00 5.80855019e-05 1.85873606e-03 ...      0.808766
# 1  [0.         0.48186029 0.65283674 0.77730606 0...      0.742612
# 2  [0.00000000e+00 5.80855019e-05 4.06598513e-04 ...      0.615479
# 3  [0.00000000e+00 5.80855019e-05 1.85873606e-03 ...      0.640733
# 4  [0.         0.33683783 0.33741868 0.33887082 0...      0.774426
# 5  [0.         0.09578299 0.09589916 0.09595725 0...      0.815018
# 6  [0.00000000e+00 5.80855019e-05 5.22769517e-04 ...      0.708767
# 7  [0.00000000e+00 5.80855019e-05 2.03299257e-03 ...      0.640127
#
#                                  Precision Test Plot  \
# 0  [0.81127185 0.81126296 0.81130119 ... 1.      ...
# 1  [0.80578448 0.84439905 0.86526435 0.88702929 0...
# 2  [0.80309745 0.80308826 0.80312573 ... 1.      ...
# 3  [0.80309745 0.80308826 0.80307908 ... 1.      ...
# 4  [0.80309745 0.83062622 0.83092662 0.83104039 0...
# 5  [0.80309745 0.81164141 0.81679426 0.8168331  0...
# 6  [0.80313491 0.80317312 0.80327639 ... 1.      ...
# 7  [0.80309745 0.80308826 0.80307908 ... 1.      ...
#
#                                     Recall Test Plot PR AUC Test   Time Fit  \
# 0  [1.00000000e+00 9.99941914e-01 9.99941914e-01 ...    0.940467  19.779837
# 1  [1.         0.9571594  0.88112698 0.77730606 0...    0.923268   0.006009
# 2  [1.00000000e+00 9.99941914e-01 9.99941914e-01 ...    0.857439   0.164112
# 3  [1.00000000e+00 9.99941914e-01 9.99883829e-01 ...    0.870835   1.426788
# 4  [1.         0.98617565 0.98600139 0.98594331 0...    0.928998   4.869970
# 5  [1.         0.99866403 0.99779275 0.99779275 0...    0.941052  68.019578
# 6  [1.00000000e+00 9.99767658e-01 9.99709572e-01 ...    0.906179  54.600921
# 7  [1.00000000e+00 9.99941914e-01 9.99883829e-01 ...    0.870664   0.424170
#
#    Time Predict
# 0      0.034010
# 1      4.606313
# 2      0.043546
# 3      0.012167
# 4      0.013342
# 5      0.795060
# 6      0.757640
# 7      0.002030
#
# [8 rows x 25 columns]

# %% [markdown]
# # ROC Curve for Train/Test

# %% [markdown]
# # Plot accuracy score for Train/Test

# %% [markdown]
# # Plot Precision/Recall/F1 for Functioning/Non-functioning Test

# %% [markdown]
# # Time fit

# %% [markdown]
# # Time predict

# %% [markdown]
# # Visualise feature importance of best model
